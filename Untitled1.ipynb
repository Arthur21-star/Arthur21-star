# %% [markdown]
# <a href="https://colab.research.google.com/github/Arthur21-star/Arthur21-star/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
tabela_clientes = pd.read_csv("/content/clientes.csv")
print(tabela_clientes)
#Series -> 1 coluna
display(tabela_clientes["idade"])
#DataFrame
# Out:
#        CustomerID  idade    sexo  tempo_como_cliente  frequencia_uso  \
# 0        349936.0   23.0    Male                13.0            22.0
# 1        100634.0   49.0    Male                55.0            16.0
# 2        301263.0   30.0    Male                 7.0             1.0
# 3        119358.0   26.0    Male                40.0             5.0
# 4        130955.0   27.0  Female                17.0            30.0
# ...           ...    ...     ...                 ...             ...
# 49995    195680.0   62.0  Female                35.0             7.0
# 49996     43477.0   36.0    Male                43.0            21.0
# 49997    169273.0   55.0    Male                42.0             8.0
# 49998    310693.0   40.0  Female                14.0            19.0
# 49999    251915.0   64.0    Male                41.0            29.0
#
#        ligacoes_callcenter  dias_atraso assinatura duracao_contrato  \
# 0                      2.0          1.0   Standard           Annual
# ...

# %%
dicionario_produtos = {"nome": ["iphone","ipad","airpod"], "preço": [5000,9000,2000], "estoque": [100,50,60]}
tabela_produtos = pd.DataFrame(dicionario_produtos)
display(tabela_produtos)
# Out:
#      nome  preço  estoque
# 0  iphone   5000      100
# 1    ipad   9000       50
# 2  airpod   2000       60
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# tabela_produtos['preço'].plot(kind='hist', bins=20, title='preço')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# tabela_produtos['estoque'].plot(kind='hist', bins=20, title='estoque')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# tabela_produtos.groupby('nome').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
lista_produtos = [
    {"nome":"iphone", "preço":5000, "estoque":100},
    {"nome":"ipad", "preço":9000, "estoque":50},
    {"nome":"airpod", "preço":2000, "estoque":60}
]
tabela_produtos2 = pd.DataFrame(lista_produtos)
display(tabela_produtos2)
# Out:
#      nome  preço  estoque
# 0  iphone   5000      100
# 1    ipad   9000       50
# 2  airpod   2000       60
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['preço'].plot(kind='hist', bins=20, title='preço')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['estoque'].plot(kind='hist', bins=20, title='estoque')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...
